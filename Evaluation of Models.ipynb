# %% [markdown]
# # 3 classic evaluation methods
# - simple holdout validation
# - k-fold validation
# - iterated k-fold validation with shuffling

# %% [markdown]
# # holdout validation

# %%
# @title
num_validation_samples = 10000
np.random.shuffle(data)

validation_data = data[:num_validation_samples]
training_data = data[num_validation_samples:]

model = get_model()
model.fit(training_data, ...)
validation_score = model.evaluate(validation_data, ...)
# at this point, tune the model, retrain, evaluate, tune it again

# once tuned, train a fresh final model on all non-test data available
model = get_model()
model.fit(np.concatenate([training_data, validation_data]), ...)
test_score = model.evaluate(test_data, ...)

# %% [markdown]
# # k-fold validation

# %%
k = 3
num_validation_samples = len(data) // k
np.random.shuffle(data)
validation_scores = []

for fold in range(k):
    validation_data = data[num_validation_samples * fold : num_validation_samples * (fold+1)]
    training_data = np.concatenate(
        data[:num_validation_samples * fold],
        data[num_validation_samples * (fold+1):])
    model = get_model()
    model.fit(training_data, ...)
    validation_score = model.evaluate(validation_data, ...)
    validation_scores.append(validation_score)

validation_score = np.average(validation_scores)

model = get_model()
model.fit(data, ...)
test_score = model.evaluate(test_data, ...)

# %% [markdown]
# # iterated k-fold validation with shuffling
# - apply this k-fold validation multiple times with shuffling the data
# - final score is the average of results
#
#
# ---

# %% [markdown]
# # improving model fit

# %% [markdown]
# # training an MNIST model with an incorrectly high learning rate

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28*28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(optimizer=keras.optimizers.RMSprop(1.),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4606 - loss: 4220.6597 - val_accuracy: 0.2277 - val_loss: 2.1103
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2322 - loss: 2.6278 - val_accuracy: 0.2079 - val_loss: 2.4779
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1926 - loss: 2.7890 - val_accuracy: 0.1682 - val_loss: 2.2713
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1794 - loss: 2.5972 - val_accuracy: 0.2011 - val_loss: 2.3246
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2061 - loss: 2.2848 - val_accuracy: 0.2047 - val_loss: 2.2141
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2189 - loss: 2.4907 - val_accuracy: 0.2034 - val_loss: 2.2189
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2039 - loss: 2.5979 - val_accuracy: 0.2545 - val_loss: 2.6271
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2107 - loss: 2.3326 - val_accuracy: 0.2567 - val_loss: 3.2223
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2093 - loss: 2.3353 - val_accuracy: 0.1938 - val_loss: 2.1773
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2029 - loss: 2.2487 - val_accuracy: 0.1894 - val_loss: 2.1390

# %% [markdown]
# # same model with an appropriate learning rate

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(optimizer=keras.optimizers.RMSprop(1e-2),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8369 - loss: 0.7959 - val_accuracy: 0.9523 - val_loss: 0.1651
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9628 - loss: 0.1306 - val_accuracy: 0.9499 - val_loss: 0.1947
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9729 - loss: 0.0985 - val_accuracy: 0.9603 - val_loss: 0.1859
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9801 - loss: 0.0769 - val_accuracy: 0.9676 - val_loss: 0.1609
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9846 - loss: 0.0565 - val_accuracy: 0.9715 - val_loss: 0.1523
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9864 - loss: 0.0487 - val_accuracy: 0.9722 - val_loss: 0.1691
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9879 - loss: 0.0505 - val_accuracy: 0.9746 - val_loss: 0.1967
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0427 - val_accuracy: 0.9718 - val_loss: 0.1940
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9899 - loss: 0.0405 - val_accuracy: 0.9727 - val_loss: 0.1995
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.9747 - val_loss: 0.1371
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9758 - val_loss: 0.1350

# %% [markdown]
# observe that overfit began after 7th epoch, validation loss started to increase

# %% [markdown]
# # regularizing the model
# - making model more generic, not specific to training data

# %% [markdown]
# # reduce the network size to prevent overfitting

# %% [markdown]
# # original model

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1.
  return results

train_data = vectorize_sequences(train_data)

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

model.fit(train_data, train_labels,
          epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.6732 - loss: 0.6195 - val_accuracy: 0.8585 - val_loss: 0.4165
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8892 - loss: 0.3586 - val_accuracy: 0.8818 - val_loss: 0.3222
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9215 - loss: 0.2570 - val_accuracy: 0.8813 - val_loss: 0.3053
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9379 - loss: 0.1988 - val_accuracy: 0.8855 - val_loss: 0.2866
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9486 - loss: 0.1617 - val_accuracy: 0.8802 - val_loss: 0.3010
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9582 - loss: 0.1379 - val_accuracy: 0.8844 - val_loss: 0.2925
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9634 - loss: 0.1169 - val_accuracy: 0.8742 - val_loss: 0.3268
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9716 - loss: 0.1025 - val_accuracy: 0.8853 - val_loss: 0.3097
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9789 - loss: 0.0824 - val_accuracy: 0.8814 - val_loss: 0.3290
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9821 - loss: 0.0728 - val_accuracy: 0.8795 - val_loss: 0.3519
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9878 - loss: 0.0605 - val_accuracy: 0.8657 - val_loss: 0.4287
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9888 - loss: 0.0537 - val_accuracy: 0.8755 - val_loss: 0.4034
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9912 - loss: 0.0427 - val_accuracy: 0.8678 - val_loss: 0.4486
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9929 - loss: 0.0376 - val_accuracy: 0.8748 - val_loss: 0.4338
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9948 - loss: 0.0305 - val_accuracy: 0.8727 - val_loss: 0.4749
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9960 - loss: 0.0257 - val_accuracy: 0.8708 - val_loss: 0.4846
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9968 - loss: 0.0222 - val_accuracy: 0.8703 - val_loss: 0.5018
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9984 - loss: 0.0171 - val_accuracy: 0.8707 - val_loss: 0.5309
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9985 - loss: 0.0134 - val_accuracy: 0.8720 - val_loss: 0.5490
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9995 - loss: 0.0098 - val_accuracy: 0.8650 - val_loss: 0.6045

# %% [markdown]
# observe that overfit began after 5th epoch

# %% [markdown]
# # replace this model with a smaller one

# %%
model = keras.Sequential([
    layers.Dense(4, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(train_data, train_labels,
          epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.6077 - loss: 0.6651 - val_accuracy: 0.8271 - val_loss: 0.5508
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8590 - loss: 0.5119 - val_accuracy: 0.8436 - val_loss: 0.4612
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8890 - loss: 0.4133 - val_accuracy: 0.8658 - val_loss: 0.3937
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9064 - loss: 0.3445 - val_accuracy: 0.8838 - val_loss: 0.3497
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9141 - loss: 0.2939 - val_accuracy: 0.8851 - val_loss: 0.3208
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9273 - loss: 0.2521 - val_accuracy: 0.8893 - val_loss: 0.2988
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9360 - loss: 0.2242 - val_accuracy: 0.8884 - val_loss: 0.2882
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9415 - loss: 0.1958 - val_accuracy: 0.8920 - val_loss: 0.2787
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9498 - loss: 0.1744 - val_accuracy: 0.8921 - val_loss: 0.2751
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9557 - loss: 0.1557 - val_accuracy: 0.8900 - val_loss: 0.2771
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9593 - loss: 0.1423 - val_accuracy: 0.8919 - val_loss: 0.2767
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9642 - loss: 0.1282 - val_accuracy: 0.8907 - val_loss: 0.2800
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9709 - loss: 0.1143 - val_accuracy: 0.8889 - val_loss: 0.2858
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9722 - loss: 0.1036 - val_accuracy: 0.8871 - val_loss: 0.2938
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9762 - loss: 0.0968 - val_accuracy: 0.8807 - val_loss: 0.3081
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9788 - loss: 0.0868 - val_accuracy: 0.8805 - val_loss: 0.3248
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9805 - loss: 0.0843 - val_accuracy: 0.8806 - val_loss: 0.3238
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9840 - loss: 0.0712 - val_accuracy: 0.8833 - val_loss: 0.3272
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9868 - loss: 0.0640 - val_accuracy: 0.8829 - val_loss: 0.3361
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9885 - loss: 0.0575 - val_accuracy: 0.8810 - val_loss: 0.3509

# %% [markdown]
# observe that overfit began after 7th epoch

# %% [markdown]
# # version of the model with higher capacity

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(512, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.6671 - loss: 0.6464 - val_accuracy: 0.8199 - val_loss: 0.4007
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8438 - loss: 0.3597 - val_accuracy: 0.8749 - val_loss: 0.2972
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9034 - loss: 0.2384 - val_accuracy: 0.8874 - val_loss: 0.2792
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9256 - loss: 0.1911 - val_accuracy: 0.8310 - val_loss: 0.3911
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9500 - loss: 0.1346 - val_accuracy: 0.8559 - val_loss: 0.4084
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9471 - loss: 0.1307 - val_accuracy: 0.8889 - val_loss: 0.3195
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9794 - loss: 0.0674 - val_accuracy: 0.8870 - val_loss: 0.3546
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9817 - loss: 0.0630 - val_accuracy: 0.8878 - val_loss: 0.3680
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9940 - loss: 0.0278 - val_accuracy: 0.8865 - val_loss: 0.3263
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9993 - loss: 0.0138 - val_accuracy: 0.8871 - val_loss: 0.4428
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9961 - loss: 0.0196 - val_accuracy: 0.8843 - val_loss: 0.3794
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9998 - loss: 0.0069 - val_accuracy: 0.8855 - val_loss: 0.4769
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8851 - val_loss: 0.5366
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9939 - loss: 0.0343 - val_accuracy: 0.8841 - val_loss: 0.4384
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8858 - val_loss: 0.5021
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8864 - val_loss: 0.5752
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 7.5732e-04 - val_accuracy: 0.8850 - val_loss: 0.6278
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 5.0605e-04 - val_accuracy: 0.8853 - val_loss: 0.6560
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 3.3368e-04 - val_accuracy: 0.8856 - val_loss: 0.6898
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 2.8686e-04 - val_accuracy: 0.8846 - val_loss: 0.7066

# %% [markdown]
# observe that overfit began after just one epoch

# %% [markdown]
# # adding L2 weight regularization to the initial movie model
# - add a cost to weights to make weights more regular

# %%
from tensorflow.keras import regularizers
model = keras.Sequential([
    layers.Dense(16, kernel_regularizer=regularizers.l2(0.002), activation="relu"),
    layers.Dense(16, kernel_regularizer=regularizers.l2(0.002), activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4
)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - accuracy: 0.6854 - loss: 0.7053 - val_accuracy: 0.8438 - val_loss: 0.5079
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8805 - loss: 0.4514 - val_accuracy: 0.8773 - val_loss: 0.4032
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9059 - loss: 0.3567 - val_accuracy: 0.8858 - val_loss: 0.3689
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.